# %%
print("Welcome To The Interactive Personal Data")

#input()-> is the user taking data!

Name=input("enter your name")
Age=int(input("enter your age"))
Height=float(input("enter your height"))
favourite_num=int(input("enter your favourite_num"))
approx_age= 2026-Age

#print()-> to display the output!

print(f"Name:{Name}", type(Name), id(Name))
print(f"Age:{Age}", type(Age), id(Age))
print(f"Height:{Height}", type(Height), id(Height))
print(f"favourite_num:{favourite_num}", type(favourite_num), id(favourite_num))
print(f"birth year:{approx_age}")
# Out:
# Welcome To The Interactive Personal Data
# enter your name piyush
# enter your age 18
# enter your height 1.3
# enter your favourite_num 218
# Name:piyush <class 'str'> 2540542772256
# Age:18 <class 'int'> 140710491891144
# Height:1.3 <class 'float'> 2540542626224
# favourite_num:218 <class 'int'> 140710491897544
# birth year:2008
